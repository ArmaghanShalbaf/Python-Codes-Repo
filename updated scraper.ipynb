# %%
import requests
from bs4 import BeautifulSoup
import urllib.parse

# Base search URL for Google Scholar or other academic databases
BASE_URL = "https://scholar.google.com/scholar?q="

# List of materials and material properties to search for
materials = ["Ti", "O2", "Al", "Cu", "TiO2", "TiAl", "TiCu"]
properties = ["Band Gap", "Young Modulus", "Density", "Energy Absorption", "Thermal Conductivity", "Specific Heat"]

# Function to search for papers based on keywords
def search_papers(materials, properties):
    results = []
    for material in materials:
        for prop in properties:
            query = f"{material} {prop}"
            print(f"Searching for: {query}")
            
            # Encode the query for the URL
            search_url = BASE_URL + urllib.parse.quote(query)
            response = requests.get(search_url)
            
            # Check if the request was successful
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')
                
                # Find all results (these selectors may vary depending on the website you're scraping)
                for result in soup.select('.gs_r.gs_or.gs_scl'):
                    title = result.select_one('.gs_rt').text
                    link = result.select_one('.gs_rt a')['href']
                    description = result.select_one('.gs_rs').text
                    results.append({'title': title, 'link': link, 'description': description})
            else:
                print(f"Failed to retrieve results for {query}. Status code: {response.status_code}")
    
    return results

# Function to display the papers found
def display_papers(papers):
    for i, paper in enumerate(papers, 1):
        print(f"{i}. Title: {paper['title']}")
        print(f"   Link: {paper['link']}")
        print(f"   Description: {paper['description']}\n")

# Main execution
papers_found = search_papers(materials, properties)
display_papers(papers_found)
# Out:
# Searching for: Ti Band Gap
# Searching for: Ti Young Modulus
# Searching for: Ti Density
# Searching for: Ti Energy Absorption
# Searching for: Ti Thermal Conductivity
# Searching for: Ti Specific Heat
# Searching for: O2 Band Gap
# Searching for: O2 Young Modulus
# Searching for: O2 Density
# Searching for: O2 Energy Absorption
# Searching for: O2 Thermal Conductivity
# Searching for: O2 Specific Heat
# Searching for: Al Band Gap
# Searching for: Al Young Modulus
# Searching for: Al Density
# Searching for: Al Energy Absorption
# Searching for: Al Thermal Conductivity
# Searching for: Al Specific Heat
# Searching for: Cu Band Gap
# Searching for: Cu Young Modulus
# Searching for: Cu Density
# Searching for: Cu Energy Absorption
# Searching for: Cu Thermal Conductivity
# Searching for: Cu Specific Heat
# Searching for: TiO2 Band Gap
# Searching for: TiO2 Young Modulus
# Searching for: TiO2 Density
# Searching for: TiO2 Energy Absorption
# Searching for: TiO2 Thermal Conductivity
# Searching for: TiO2 Specific Heat
# Searching for: TiAl Band Gap
# Searching for: TiAl Young Modulus
# Searching for: TiAl Density
# Searching for: TiAl Energy Absorption
# Searching for: TiAl Thermal Conductivity
# Searching for: TiAl Specific Heat
# Searching for: TiCu Band Gap
# Searching for: TiCu Young Modulus
# Searching for: TiCu Density
# Searching for: TiCu Energy Absorption
# Searching for: TiCu Thermal Conductivity
# Searching for: TiCu Specific Heat
# 1. Title: Band gap narrowing of titanium dioxide by sulfur doping
#    Link: https://pubs.aip.org/aip/apl/article/81/3/454/44283
#    Description: … band calculations, mixing of the S 3p states with the valence band was found to contribute
# to the band gap … the S doping into the lattice of TiO2 contributes to the band gap narrowing. …
#
# 2. Title: Band gap and photocatalytic properties of Ti-substituted hydroxyapatite: Comparison with anatase-TiO2
#    Link: https://www.sciencedirect.com/science/article/pii/S1381116911000288
#    Description: … the band gap of Ti-HAP experimentally and theoretically in comparison with anatase-TiO 2 .
# The experimental band gaps of HAP, Ti-… The DFT-calculated band gaps of HAP, Ti-HAP, and …
#
# 3. Title: The band gap modulation of monolayer Ti 2 CO 2 by strain
#    Link: https://pubs.rsc.org/en/content/articlehtml/2015/ra/c5ra01586c
#    Description: … investigated the band gap modulation of O-terminated Ti 2 C (Ti 2 … Ti 2 CO 2 could undergo
# an indirect to direct band gap … Similarly, the band gap modulation also occurs in monolayer …
#
# 4. Title: Band gap and stability in the ternary intermetallic compounds NiSnM (M=Ti,Zr,Hf): A first-principles study
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.51.10443
#    Description: … and band-structure … of the microscopicmechanisms in the formation of the band gap in the
# o. phase of NiSnM, and of the difFerences between these compounds and related systems, …
#
# 5. Title: The Role of Interstitial Sites in the Ti3d Defect State in the Band Gap of Titania
#    Link: https://www.science.org/doi/abs/10.1126/science.1159846
#    Description: … assumed to cause the Ti3d defect state in the band gap of rutile TiO 2 (110). From … Ti
# interstitials in the near-surface region may be largely responsible for the defect state in the band gap…
#
# 6. Title: Band gap states of Ti, V, and Cr in 4H–silicon carbide
#    Link: https://pubs.aip.org/aip/apl/article-abstract/71/1/110/67850
#    Description: … concentration changes of band gap states. Thus, six levels are identified in the band gap: Cr
# … at 0.97 eV, and two Ti levels at 0.13 and 0.17 eV below the conduction band edge. © 1997 …
#
# 7. Title: Band-gap narrowing of titanium dioxide by nitrogen doping
#    Link: https://iopscience.iop.org/article/10.1143/JJAP.40.L561/meta
#    Description: … Titanium dioxides have been extensively studied for photochemical applications and … under
# visible-light irradiation (smaller than titanium dioxide’s band gap of 3.2 eV or λ > 380 nm) has …
#
# 8. Title: Is the Band Gap of Pristine TiO2 Narrowed by Anion- and Cation-Doping of Titanium Dioxide in Second-Generation Photocatalysts?
#    Link: https://pubs.acs.org/doi/abs/10.1021/jp065659r
#    Description: … formation of color centers, and that while band gap narrowing is not an unknown occurrence
# in … different band gap electronic structures. Among others, these color centers include Ti 3+ …
#
# 9. Title: Band gap narrowing of titanium oxide semiconductors by noncompensated anion-cation codoping for enhanced visible-light photoactivity
#    Link: https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.103.226401
#    Description: … Ti atoms and 72 O atoms to model bulk anatase TiO2. To overcome the well-known band gap
# … metals [20], producing an intrinsic band gap of 3.2 eV. The ‘‘climbing image nudged elastic …
#
# 10. Title: Importance of the band gap energy and flat band potential for application of modified TiO2 photoanodes in water photolysis
#    Link: https://www.sciencedirect.com/science/article/pii/S0378775307024214
#    Description: … The ionic radius of Sn 4+ equals to 0.071 nm and is slightly greater than that of Ti 4+ (0.068
# nm). However, the TiO 2 –SnO 2 forms a solid solution over a full compositional range above …
#
# 11. Title: Elastic moduli of cast Ti–Au, Ti–Ag, and Ti–Cu alloys
#    Link: https://www.sciencedirect.com/science/article/pii/S010956410500240X
#    Description: … the alloy phases, while the Young's moduli and Poisson's ratios of the … Young's modulus of
# the titanium when the alloy phase was single α. The increase in the Young's modulus of the Ti…
#
# 12. Title: Development of a new β Ti alloy with low modulus and favorable plasticity for implant material
#    Link: https://www.sciencedirect.com/science/article/pii/S0928493115306822
#    Description: … Young's modulus of 44 GPa for HR specimen and 48 GPa for SA specimen which are very
# close to the extreme of Young's modulus … In short, the designed alloy has low elastic modulus …
#
# 13. Title: Origin of low Young modulus of multicomponent, biomedical Ti alloys-Seeking optimal elastic properties through a first principles investigation
#    Link: https://www.sciencedirect.com/science/article/pii/S1751616118303539
#    Description: … of the polycrystalline Young modulus of Ti-… Young modulus values are equal or similar to
# that of human bones. Some electronic-based guidelines for designing new multicomponent β-Ti …
#
# 14. Title: Beta Ti alloys with low Young's modulus
#    Link: https://www.jstage.jst.go.jp/article/matertrans/45/8/45_8_2776/_article/-char/ja/
#    Description: … Ti alloys with low elastic modulus. This work aims to experimentally measure the composition
# dependence of Young’s modulus … low Young’s modulus Ti alloys, using simple Ti-V and Ti-…
#
# 15. Title: Dynamic Young's Modulus and Mechanical Properties of Ti− Hf Alloys
#    Link: https://www.jstage.jst.go.jp/article/matertrans/45/5/45_5_1549/_article/-char/ja/
#    Description: … of microstructure and Young’s modulus values… Young’s modulus and mechanical properties
# of Ti–Hf alloys, attempting to find a binary Ti–Hf alloy that gives a good balance of low Young…
#
# 16. Title: Young's modulus and damping of Ti 6Al 4V alloy as a function of heat treatment and oxygen concentration
#    Link: https://www.sciencedirect.com/science/article/pii/092150939090097M
#    Description: … In the Ti-6AI-4V alloy the volume fractions and … Young's modulus depends not only on texture
# but on heat treatment as well. The published literature lists Young's modulus values of the Ti…
#
# 17. Title: Biomedical titanium alloys with Young's moduli close to that of cortical bone
#    Link: https://academic.oup.com/rb/article-abstract/3/3/173/1752924
#    Description: … Ti–12Cr, the biological and mechanical properties of the titanium alloys with low Young’s
# modulus and changeable Young’s modulus … having the lower Young's modulus shows greater …
#
# 18. Title: Effect of Zr and Sn on Young's modulus and superelasticity of Ti–Nb-based alloys
#    Link: https://www.sciencedirect.com/science/article/pii/S0921509306020351
#    Description: … alloys Ti–24Nb–4Zr–7.5Sn with single β microstructure has the lowest Young's modulus of
# … and superelasticity of water quenched quaternary Ti–Nb–Zr–Sn alloys were investigated in …
#
# 19. Title: First principles theoretical investigations of low Young's modulus beta Ti–Nb and Ti–Nb–Zr alloys compositions for biomedical applications
#    Link: https://www.sciencedirect.com/science/article/pii/S0928493115000715
#    Description: … Next we study Young's modulus of bcc β phase Ti–Nb and Ti–Nb–Zr compositions in different
# crystallographic directions. The Young's modulus in a direction with directions cosines l 1 , …
#
# 20. Title: Young's modulus and mechanical properties of Ti-29Nb-13Ta-4.6Zr in relation to α″ martensite
#    Link: https://link.springer.com/article/10.1007/s11661-002-0299-7
#    Description: … and its influence on Young’s modulus and mechanical properties of forged Ti-29Nb-13Ta-4.6Zr
# (… , lower strength and hardness but nearly identical Young’s modulus in the studied alloy. …
#
# 21. Title: A density-functional study of small titanium clusters
#    Link: https://pubs.aip.org/aip/jcp/article-abstract/113/24/11127/452387
#    Description: … density-functional theory with a local spin density approximation. We find that the inner-shells
# (3s3p) of the titanium … We have obtained the ground state of titanium clusters, Ti7 is found …
#
# 22. Title: Density-functional study of the thermodynamic properties and the pressure–temperature phase diagram of Ti
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.80.104116
#    Description: … from the integration over the electronic density of states. The … The thermodynamic properties
# of α and ω Ti calculated by … K total energy calculated from bcc Ti is incorrect. This problem …
#
# 23. Title: Density functional calculations of Ti-enhanced
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.71.054103
#    Description: … the resulting bulk content from Ti adsorption, we should extrapolate HSubst as a function of
# the Ti surface density, for instance defined as the number of substituted Ti atoms per unit sur…
#
# 24. Title: Synthesis of near net shape high density TiB/Ti composite
#    Link: https://www.sciencedirect.com/science/article/pii/S0921509397006436
#    Description: … densities on applied pressures and B/Ti atomic ratios was measured. As shown in Fig. 3, a
# density of nearly 100% is obtained in the B/Ti… of composite densities with B/Ti atomic ratio at a …
#
# 25. Title: Density, molar volume, and surface tension of liquid Al-Ti
#    Link: https://link.springer.com/article/10.1007/s11661-016-3886-8
#    Description: … compositions, density and surface … -Ti system, we find the largest values for pure titanium
# and the smallest for pure aluminum, which amount to ρ( L,Ti ) = 4.12 ± 0.04 g cm −3 and γ( L,Ti ) …
#
# 26. Title: Dislocation density based model for plastic deformation and globularization of Ti-6Al-4V
#    Link: https://www.sciencedirect.com/science/article/pii/S0749641913000910
#    Description: … Although Ti-6Al-4V has numerous salient properties, its usage … evolution of immobile
# dislocation density and excess vacancy … of hot forming and heat treatment of Ti-6Al-4V, can also …
#
# 27. Title: Oxide chemistry and local structure of  studied by density-functional theory supercell calculations
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.69.144118
#    Description: … in the Zr/Ti arrangement and composition through first-principles density-functional-theory
# (… -rich rhombohedral, 50/50 monoclinic, and Ti-rich tetragonal phases of PZT and to examine …
#
# 28. Title: Geometrically necessary dislocation density distributions in Ti–6Al–4V deformed in tension
#    Link: https://www.sciencedirect.com/science/article/pii/S1359645411004915
#    Description: … density measurements for deformed Ti–6Al–4V. Jones and Hutchinson [1] performed detailed
# TEM work characterizing dislocation types in Ti… so that dislocation densities were relatively …
#
# 29. Title: A novel type of Co–Ti–Cr-base γ/γ′ superalloys with low mass density
#    Link: https://www.sciencedirect.com/science/article/pii/S1359645417304998
#    Description: … Co–Ti–Cr superalloy is presented with a mass density ∼ 14 % … fraction compared to a binary
# Co-Ti alloy to more than 60 %. … , even more so when it is normalized by the mass density. …
#
# 30. Title: The effect of SLM process parameters on density, hardness, tensile strength and surface quality of Ti-6Al-4V
#    Link: https://www.sciencedirect.com/science/article/pii/S2214860418305670
#    Description: … In this paper, we printed Ti-6Al-4V SLM parts based on Taguchi … in our previous research
# such as density, strength, elongation, … similarity between hardness and density which is highly …
#
# 31. Title: [HTML][HTML] Energy absorption characteristics and preparation of porous titanium with high porosity
#    Link: https://www.sciencedirect.com/science/article/pii/S235249282201844X
#    Description: … Furthermore, the optimal choice of porous titanium for each relative density at the … envelope
# of energy absorption diagram. The energy absorption property of porous titanium improves …
#
# 32. Title: Functionally graded Ti‐6Al‐4V meshes with high strength and energy absorption
#    Link: https://onlinelibrary.wiley.com/doi/abs/10.1002/adem.201500086
#    Description: … high energy absorption capability.2, … energy absorption,4, 5 These mutually opposing
# requirements of high porosity and mechanical strength in conjunction with high energy absorption …
#
# 33. Title: Early plastic deformation behaviour and energy absorption in porous β-type biomedical titanium produced by selective laser melting
#    Link: https://www.sciencedirect.com/science/article/pii/S1359646218302926
#    Description: … Energy absorption is a critical consideration in the design of porous structures design. This
# work studied the energy absorption … with a high elastic energy absorption, a low Young's …
#
# 34. Title: Enhancing specific energy absorption of additively manufactured titanium lattice structures through simultaneous manipulation of architecture and constituent material
#    Link: https://www.sciencedirect.com/science/article/pii/S221486042200286X
#    Description: … attractive to energy absorbing applications. In the present work, a series of titanium gyroid
# … fusion (L-PBF) to enhance the specific energy absorption (SEA) through manipulation of the …
#
# 35. Title: Fabrication and energy absorption properties of titanium foam with CaCl2 as a space holder
#    Link: https://www.sciencedirect.com/science/article/pii/S0921509317312923
#    Description: … of the holes in the titanium foam challenge the … energy absorption properties of titanium
# foam because most current research focuses on the biocompatibility and permeability of titanium …
#
# 36. Title: Effects of internal porosity and crystallographic texture on Charpy absorbed energy of electron beam melting titanium alloy (Ti-6Al-4V)
#    Link: https://www.sciencedirect.com/science/article/pii/S0921509318315211
#    Description: … the Charpy absorbed energy properties of a titanium alloy (Ti-6Al-… EBM Ti-6Al-4V is known
# to be a two-phase material with … β texture in AM Ti-6Al-4V is dictated by the strongest thermal …
#
# 37. Title: Energy absorption in closed-cell Al-Zn-Mg-Ca-Ti foam
#    Link: https://www.jstage.jst.go.jp/article/matertrans/43/7/43_7_1778/_article/-char/ja/
#    Description: … impact energy absorption. In this study, modification of solid in a closed-cell Al– Ca–Ti foam
# … of Zn and Mg for enhancement of energy absorption. Samples with dimensions of 100 × 100 …
#
# 38. Title: Mechanisms of laser energy absorption and melting behavior during selective laser melting of titanium-matrix composite: Role of ceramic addition
#    Link: https://iopscience.iop.org/article/10.1088/1361-6463/abcdce/meta
#    Description: … The laser energy absorption and melting behavior of ceramic reinforced metal matrix … of
# ceramic addition on the laser energy absorption and powder melting behaviors during SLM of …
#
# 39. Title: Effect of transition metals on energy absorption during strain-controlled fatigue of an aluminum alloy
#    Link: https://www.sciencedirect.com/science/article/pii/S0142112316000530
#    Description: … fatigue failure process is the energy-absorption process. It is … of Ti–V–Zr-rich phases
# influence the strain energy density … (Ti, Zr and V) content on the changes of strain energy density …
#
# 40. Title: Damage and energy absorption characteristics of glass fiber reinforced titanium laminates to low-velocity impact
#    Link: https://www.tandfonline.com/doi/abs/10.1080/15376494.2021.1974618
#    Description: … the case of titanium (Ti)/glass fiber reinforced plastic (GFRP) laminates, a titanium layer crack
# … Nevertheless, the bottom titanium layer achieving energy absorption by plastic deformation …
#
# 41. Title: Thermal conductivity and microstructure of Ti-doped graphite
#    Link: https://www.sciencedirect.com/science/article/pii/S0008622302004293
#    Description: … crystals should exhibit further high thermal conductivity. Therefore, it can be concluded that
# the thermal conductivity varied with the concentration of Ti dopant because of the average …
#
# 42. Title: Enhanced thermal conductivity in copper matrix composites reinforced with titanium-coated diamond particles
#    Link: https://www.sciencedirect.com/science/article/pii/S1359646211005641
#    Description: … of thermal conductivity in Cu/diamond composites is still not very clear. We describe in this
# paper the greatly enhanced thermal conductivity of Cu matrix composites reinforced with Ti-…
#
# 43. Title: The thermal and electrical conductivity of titanium and its alloys
#    Link: https://www.sciencedirect.com/science/article/pii/0022508861900649
#    Description: … for titanium and six titanium alloys. The lattice component of thermal conductivity of titanium
# … the thermal conductivity, K, with the absolute temperature, electrical resistivity ratio, T/Q, of …
#
# 44. Title: Thermal conductivity and interface thermal conductance in composites of titanium with graphene platelets
#    Link: https://asmedigitalcollection.asme.org/heattransfer/article-abstract/136/6/061301/372537
#    Description: … The thermal conductivity of ZrO 2 film is very small (K = 1.52 Wm −1 K −1 ) so that it does not
# mask the measurement of the thermal conductivity of either Ti or Ti-GP-Ti composite film. Au …
#
# 45. Title: Influence of thermal conductivity on wear when machining titanium alloys
#    Link: https://www.sciencedirect.com/science/article/pii/S0301679X08001618
#    Description: … For illustration, we consider thermal conductivity data for commercially pure titanium (CPT) …
# The figure clearly shows that the thermal conductivity of CPT at atmospheric pressure differs …
#
# 46. Title: Thermal Conductivity and Thermoelectric Power of Rutile (Ti)
#    Link: https://journals.aps.org/pr/abstract/10.1103/PhysRev.139.A1655
#    Description: … The thermal conductivity Eand the thermoelectric powerQ of … The thermal conductivity of
# the pure crystals is similar to that … It was our aim to measure the thermal conductivity of the two …
#
# 47. Title: Thermal conductivity of metals and alloys
#    Link: https://www.tandfonline.com/doi/abs/10.1179/imtr.1986.31.1.197
#    Description: … conductivity, it throws light on the fundamental interaction processes which occur within
# metallic systems, so that the study of thermal conductivity has … in the section on Ti-base alloys, …
#
# 48. Title: Cross-plane thermal conductivity of (Ti, W) N/(Al, Sc) N metal/semiconductor superlattices
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.93.045311
#    Description: … We have developed epitaxial (Ti,W)N/(Al,Sc)N metal/semiconductor superlattices with …
# lower thermal conductivity compared to the parent TiN/(Al,Sc)N superlattice system. The (Ti,W)N/(…
#
# 49. Title: Effects of spark plasma sintering temperature on densification, hardness and thermal conductivity of titanium carbide
#    Link: https://www.sciencedirect.com/science/article/pii/S0272884218311994
#    Description: … thermal conductivity, this factor is one of the significant properties of TiC ceramics. Having
# the thermal stability and thermal conductivity … Hence, knowing the thermal conductivity of TiC …
#
# 50. Title: Effect of lattice defects on thermal conductivity of Ti-doped, Y2O3-stabilized ZrO2
#    Link: https://www.sciencedirect.com/science/article/pii/S1359645413004163
#    Description: … vacancy by interstitial Ti 4+ ions which increases the thermal conductivity at high Ti doping
# content … properties, Ti-doped YSZ is believed to be a promising candidate for thermal barrier …
#
# 51. Title: Physical properties of titanium. III. The specific heat
#    Link: https://pubs.aip.org/aip/jap/article-abstract/34/8/2350/363198
#    Description: … The specific heat of titanium has been measured over a temperature range from 600 to
# 1345… of the apparent specific heat of the a titanium, especially where this specific heat is high. …
#
# 52. Title: Experimental study of surface tension, specific heat and thermal diffusivity of liquid and solid titanium
#    Link: https://www.sciencedirect.com/science/article/pii/S0009261415006922
#    Description: … In summary, the surface tension, specific heat and thermal diffusivity of titanium were
# measured by the electromagnetic levitation and oscillating drop technique, drop calorimetry and …
#
# 53. Title: Specific heat of well-characterized Ti at 0 and 7 T
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.25.5907
#    Description: … , and specificheat datawith … specific heats of the samplesin a 7-T field are compared with
# a theoretical prediction and with recent measurements of the lowtemperature specific heats of …
#
# 54. Title: Magnetic susceptibility and low-temperature specific heat of high-purity titanium
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.2.235
#    Description: … Specific heats of several pure titanium samples (weighing about 30 g each) were measured
# between 1.and 6 K in a He' cryostat. "… Lour-temperature specific heat of highpurity titanium. …
#
# 55. Title: Low-temperature specific heat of body-centered cubic Ti-V alloys
#    Link: https://journals.aps.org/pr/abstract/10.1103/PhysRev.126.2030
#    Description: … Ti-V alloys. They compared these with transition temperatures calculated from electronic
# specific heat … The accuracy of the electronic specific heat values for four Ti-V alloy compositions …
#
# 56. Title: Specific heat measurement of stable and metastable liquid Ti–Al alloys
#    Link: https://link.springer.com/article/10.1007/s00339-010-6168-0
#    Description: … For the development of Ti–Al alloys, the measurement of the specific heat is very important.
# The objective of this letter is to determine the specific heat of liquid Ti– 20at.%Al and Ti–51at.…
#
# 57. Title: Specific Heats of Some Cubic Superconducting Titanium-Molybdenum Alloys between 1.1 and 4.3° K
#    Link: https://journals.aps.org/pr/abstract/10.1103/PhysRev.123.1986
#    Description: … The specific heats of four bcc Ti-Moalloys have been … Then too, specific heat measurements
# as a function oftemperature and … temperature specific heats of Ti-rich bcc Ti-Mo alloys is of …
#
# 58. Title: Lattice specific heat and thermal expansion of titanium
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.19.3323
#    Description: … The second-order elastic (SOE) constarits of Ti at various temperatures were measured …
# specific heat of Ti in the temperature range 15-300 K. The experimental dispersion relation in Ti …
#
# 59. Title: Metal-insulator transitions in  single crystals: Crystal characterization, specific heat, and electron paramagnetic resonance
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.14.1429
#    Description: … 2 In this paper, we report specific-heat data obtained on Ti4Q,single crystals; the enthalpies
# and … is the same for the coefficient of the electronic specific heat as for the Pauli susceptibility. …
#
# 60. Title: Low-dimensional phonon specific heat of titanium dioxide nanotubes
#    Link: https://pubs.aip.org/aip/apl/article/87/3/031901/330324
#    Description: … specific heat approaches that of bulk anatase at high temperatures. Below about 50 K the
# nanotube specific heat … the enhanced specific heat of multiwalled titanium dioxide (anatase …
#
# 61. Title: Electron-Transfer Reaction of Oxygen Species on TiO2 Nanoparticles Induced by Sub-band-gap Illumination
#    Link: https://pubs.acs.org/doi/abs/10.1021/jp909678e
#    Description: … in water or air by the band gap excitation of TiO 2 with sun light… hole pairs generated by the
# band gap irradiation, followed by … TiO 2 start in principle with band gap illumination. We have …
#
# 62. Title: Oxygen Vacancy Origin of the Surface Band-Gap State of
#    Link: https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.104.036806
#    Description: … O2 eliminates the band-gap state so it was concluded that the state originates from Ob vac
# that are themselves filled by oxygen atoms upon exposure to O2 [… creation of band-gap states …
#
# 63. Title: Band gap narrowing of ZnO: N films by varying rf sputtering power in O2∕ N2 mixtures
#    Link: https://pubs.aip.org/avs/jvb/article/25/4/L23/590597
#    Description: … band gap and band-edge positions compared to Ti O 2 . However, ZnO has a direct band
# gap … Like Ti O 2 , the band gap of ZnO ( 3.3 eV ) is too large to effectively use visible light, …
#
# 64. Title: Adsorption and Reactions of O2 on Anatase TiO2
#    Link: https://pubs.acs.org/doi/abs/10.1021/ar400312t
#    Description: … band gap near the bottom of the conduction band. Oxygen adsorption involves the transfer
# of one or more of these excess electrons to an O 2 molecule at the TiO 2 surface. This results …
#
# 65. Title: Oxygen adsorption on Au clusters and a rough Au (111) surface: The role of surface flatness, electron confinement, excess electrons, and band gap
#    Link: https://pubs.aip.org/aip/jcp/article-abstract/118/9/4198/535642
#    Description: … O2 binds to such clusters, in spite of the fact that the system is a metal and there is no band
# gap… this that the existence of a band gap is not essential to the binding of O2 to gold, and that …
#
# 66. Title: The formation and stability of the superoxide radical (O2−) on rock‐forming minerals: Band gaps, hydroxylation state, and implications for Mars oxidant chemistry
#    Link: https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1029/2007JE003001
#    Description: We have examined the generation and stability of O 2 − on TiO 2 and albite, a common Na
# feldspar. We were not able to produce thermally stable superoxide on albite, in contrast to the …
#
# 67. Title: A comparative study of O2 adsorbed carbon nanotubes
#    Link: https://www.sciencedirect.com/science/article/pii/S0009261403013642
#    Description: … There occurs a band gap of ∼0.2 eV between the top of the valance band of SWNT (E V
# ) and empty Oppπ ∗ (↓) band. As pointed out by recent studies [14], [15] this situation …
#
# 68. Title: FTIR Study of the Impact of PC[60]BM on the Photodegradation of the Low Band Gap Polymer PCPDTBT under O2 Environment
#    Link: https://pubs.acs.org/doi/abs/10.1021/acs.chemmater.5b00268
#    Description: … (23, 24) This work focuses on the investigation of the degradation process of the low band
# gap polymer PCPDTBT, both in pristine films and blended with PC[60]BM. PCPDTBT is a …
#
# 69. Title: NaTaO3 photocatalysts of different crystalline structures for water splitting into H2 and O2
#    Link: https://pubs.aip.org/aip/apl/article/89/21/211904/327970
#    Description: … -gel specimen had a slightly larger band gap. The band structure analysis revealed an indirect
# band gap for the sol-gel Na Ta O 3 , contrary to the direct band gap of the solid-state one…
#
# 70. Title: Influence of Ar/O2 gas ratios on the crystal quality and band gap of Zn1− xCdxO thin films
#    Link: https://www.sciencedirect.com/science/article/pii/S0022024804012850
#    Description: … for the influence of Ar/O 2 gas ratios on the band gap of Zn 1− x Cd x O thin films. By using …
# and reach crystal lattice sites, so the band gap (E g ) decreases. The band gap (E g ) for Zn 1− …
#
# 71. Title: Mechanical properties of (U, Ce) O2
#    Link: https://www.sciencedirect.com/science/article/pii/S092583889800190X
#    Description: … between the Young's modulus and the Vickers hardness obtained for (U,Ce)O 2 irrespective
# of porosity. The yield stress of (U,Ce)O 2 evaluated from both the Young's modulus and the …
#
# 72. Title: Study of the thermodynamic properties of (U, Ce) O2
#    Link: https://www.sciencedirect.com/science/article/pii/S0022311597000767
#    Description: … the Young and shear modulus increased with decreasing bond length. However, the Young
# and shear modulus of (U, … The Young modulus for UO 2 (E o) obtained in the present study is …
#
# 73. Title: Operando reduction of elastic modulus in (Pr, Ce) O2− δ thin films
#    Link: https://www.sciencedirect.com/science/article/pii/S1359645415301142
#    Description: … This U overestimates the lattice constant a and Young's modulus of CeO 2 by ∼ 1% and
# ∼ 14%, respectively. However, because the chemical expansion coefficient is accurately …
#
# 74. Title: Physico-chemical properties of (U, Ce) O2
#    Link: https://www.sciencedirect.com/science/article/pii/S0925838898004290
#    Description: … the change of it can be evaluated from the Young's modulus and the atomic volume in (U,Ce)…
# r 1 r 2 0 The strain ϵ is given by dr/r, thus Young's modulus E is given by, E= d σ d ϵ r→r 0 ≅…
#
# 75. Title: Sound speeds in and mechanical properties of (U,Pu)O2−x
#    Link: https://www.tandfonline.com/doi/abs/10.1080/00223131.2017.1397564
#    Description: … and the result of Young's modulus showed that porosity was the most important factor to
# decrease Young's modulus. Temperature dependence on Young's modulus was also evaluated …
#
# 76. Title: Mechanical properties of (U, Ce) O2 with and without Nd or Zr
#    Link: https://www.sciencedirect.com/science/article/pii/S0925838801015572
#    Description: … The elastic moduli such as Young’s modulus and shear modulus decrease with increasing
# M atoms content. The values of micro-Vickers hardness and yield stress also decrease with …
#
# 77. Title: Elastic moduli of Ce0. 9Gd0. 1O2− δ at high temperatures under controlled atmospheres
#    Link: https://www.sciencedirect.com/science/article/pii/S0167273811003651
#    Description: … The Young's modulus and the shear modulus of Ce 0.9 Gd 0.1 O 2 − δ (GDC) were evaluated
# by using a resonance method in the temperature range from room temperature to 1273 K …
#
# 78. Title: Thermal and mechanical properties of (U, Er) O2
#    Link: https://www.sciencedirect.com/science/article/pii/S0022311509000269
#    Description: … The Young’s modulus of the pellets was evaluated from the longitudinal and shear sound …
# The method to evaluate the Young’s modulus from the sound velocities was explained in detail …
#
# 79. Title: Young's modulus measurements of thin films using micromechanics
#    Link: https://pubs.aip.org/aip/jap/article-abstract/50/11/6761/291005
#    Description: … a comprehensive study of Young's modulus in thin films, but … with other measurements of
# Young's modulus since so little work … a wet O2 atmosphere exhibited a noticeably lower Young's …
#
# 80. Title: Comparison of thermomechanical properties of (Ux, Th1-x) O2,(Ux, Pu1-x) O2 and (Pux, Th1-x) O2 systems
#    Link: https://www.sciencedirect.com/science/article/pii/S002231151831211X
#    Description: … of the actinide oxides, Young's modulus (Y) is estimated. Y of … Young's modulus decreases
# linearly with temperature, which … bulk modulus, Young's modulus and shear modulus follows ε …
#
# 81. Title: Global model of Ar, O2, Cl2, and Ar/O2 high‐density plasma discharges
#    Link: https://pubs.aip.org/avs/jva/article-abstract/13/2/368/152713
#    Description: … O2, Cl2, and Ar/O2 discharges and compare with available experimental data. In Ar, we find
# that the ion density … For mixtures of Ar and O2, we find that at a fixed ratio of Ar to O2 flowrates…
#
# 82. Title: Electron Attachment and Detachment. I. Pure O2 at Low Energy
#    Link: https://pubs.aip.org/aip/jcp/article-abstract/44/5/1870/83456
#    Description: … Therefore, if we plot the attachment frequency divided by the product density versus the
# ratio of oxygen to carbon dioxide densities, we will obtain a straight line with an intercept of k2 …
#
# 83. Title: Effect of O2(a1Δg) on plasma structures in oxygen radio frequency discharges
#    Link: https://pubs.aip.org/aip/jap/article-abstract/80/11/6142/178883
#    Description: … We explain the dependence of charged particle density on pressure by the variation of O2(a1Δg)
# density. Two cases of surface materials that differ from each other on the loss …
#
# 84. Title: Electron Attachment and Detachment. II. Mixtures of O2 and CO2 and of O2 and H2O
#    Link: https://pubs.aip.org/aip/jcp/article-abstract/45/11/4316/211296
#    Description: … As in the 02-C02 mixtures, the data are presented as the attachment frequency divided by
# the product density [02J[H20J versus ratio of O2 density to H20 density. The previously deter…
#
# 85. Title: Density Gradient Measurements of O2 Dissociation in Shock Waves
#    Link: https://pubs.aip.org/aip/jcp/article-abstract/55/8/4017/87178
#    Description: … The slight rise following the minimum of the "dip" in the density gradient profiles observed
# in this study indicates that, despite the retarding effects of O2 depletion and cooling due to …
#
# 86. Title: density measurement in a dielectric barrier discharge in N2 and N2 with small O2 admixtures
#    Link: https://iopscience.iop.org/article/10.1088/0963-0252/16/3/010/meta
#    Description: … The quenching rate constants by O2 and O are (2.3 ± 0.4) × 10−12 cm3 s −1 [27] … O2, O that
# are present due to the leak of the vacuum chamber (that gives an initial 10 ppm amount of O2 …
#
# 87. Title: Equations for O2 and CO2 solubilities in saline and plasma: combining temperature and density dependences
#    Link: https://journals.physiology.org/doi/abs/10.1152/japplphysiol.01124.2016
#    Description: … and the densities of the solutions compared with water density. The data sources for the
# solubilities did not provide the densities, so we used 1.020 g/ml, the average plasma densities …
#
# 88. Title: The measurement of O2 number density by absorption of Lyman α
#    Link: https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1029/JA079i013p01965
#    Description: … 2 number density obtained from … density from other rocket techniques: grenades, falling
# sphere, and Pitot tube. All launches were from Wallops Island, Virginia. The atmospheric density …
#
# 89. Title: O2 in interstellar molecular clouds
#    Link: https://iopscience.iop.org/article/10.1086/312854/meta
#    Description: … O2 integrated intensities with those of CO in a 18 similarly sized beam and obtain 3 j upper
# limits for the O2… the column density in the upper level of the transition, and the total O2 column …
#
# 90. Title: Oxygen depletion in dense molecular clouds: a clue to a low O2 abundance?
#    Link: https://www.aanda.org/articles/aa/abs/2011/06/aa16328-10/aa16328-10.html
#    Description: … As the density increases, the fraction of UDO increases whereas that of atomic oxygen
# decreases. At densities high … We use this value, as the extrapolation to a density of 2 × 10 4 …
#
# 91. Title: Visible absorption cross sections and integrated absorption intensities of molecular oxygen (O2 and O4)
#    Link: https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1029/98JD02799
#    Description: … to O2 monomer absorption with small contributions from 02-02 to O2-N2 collision-induced
# absorption (… bands and are neglected in the analysis of the O2 bands), and in the pure oxygen …
#
# 92. Title: Near‐infrared absorption cross sections and integrated absorption intensities of molecular oxygen (O2, O2‐O2, and O2‐N2)
#    Link: https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1029/1999JD901171
#    Description: … , 1999] that these absorption continua can be represented by … p(O2)). This subdivision
# provides a simple model with which to reproduce the intensity and shape of the near-lR absorption …
#
# 93. Title: Absorption measurements of oxygen between 330 and 1140 nm
#    Link: https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1029/JD095iD11p18577
#    Description: … The O2 absorption bands centered at 359.6, 379.8, and 477.4 nin were also measured at
# 196 K. Compared to the bands at 296 K the bands becatne narrower and the peak heights …
#
# 94. Title: Absorption Cross Sections of O2(a1Δg) and O2(X3Σg−) in the Region from 1087 to 1700 Å
#    Link: https://cdnsciencepub.com/doi/abs/10.1139/p75-236
#    Description: … On a essay6 de mesurer les sections efficaces d'absorption de O2 dans I'Ctat metastatle
# ulA,, entre 1087 et 1700 A. L'absorption est mesurable (o, r 3 x 10-l9 crn2) a partir d'environ …
#
# 95. Title: O2−O2 and O2−N2 collision-induced absorption mechanisms unravelled
#    Link: https://www.nature.com/articles/s41557-018-0015-x
#    Description: … the underlying absorption mechanism … absorption spectra. To this end, we present the first
# theoretical line shape study of electronic transitions in molecular collision-induced absorption. …
#
# 96. Title: Effect of Solvent on the O2(a1Δg) → O2(b1Σg+) Absorption Coefficient
#    Link: https://pubs.acs.org/doi/abs/10.1021/acs.jpca.5b05131
#    Description: … The solvent-dependent absorption coefficients at the band maximum, ε max , range from
# 5 … Through the Strickler–Berg equation, we also used these absorption data to obtain the …
#
# 97. Title: An improved H2/O2 mechanism based on recent shock tube/laser absorption measurements
#    Link: https://www.sciencedirect.com/science/article/pii/S0010218010002774
#    Description: An updated H 2 /O 2 reaction mechanism is presented that incorporates recent reaction rate
# determinations in shock tubes from our laboratory. These experiments used UV and IR laser …
#
# 98. Title: Photoionization and Absorption Cross Sections of O2 and N2 in the 600‐ to 1000‐Å Region
#    Link: https://pubs.aip.org/aip/jcp/article-abstract/41/2/321/209175
#    Description: … The major objective of this research was to determine those absorption and photoionization
# cross sections in N2 and O2 with k and ki greater than about 10 em-I, although coefficients …
#
# 99. Title: Excitation of the b 1Σ+ g state of O2 by low energy electrons
#    Link: https://pubs.aip.org/aip/jcp/article/69/3/1055/215938
#    Description: … Since we do not know how to modify their cross section to predict rotational excitation at
# energies well above threshold, we will absorb any such excitation in the cross sections for …
#
# 100. Title: Oxygen K-edge absorption spectra of O2, CO and CO2
#    Link: https://www.sciencedirect.com/science/article/pii/0375960185907777
#    Description: Using a recently developed scheme for soft X-ray detection, we have recorded the oxygen K-edge
# absorption spectra of O 2 , CO and CO 2 to ≈ 500 eV above the ionization threshold …
#
# 101. Title: Modelling the thermal conductivity of (UxTh1− x) O2 and (UxPu1− x) O2
#    Link: https://www.sciencedirect.com/science/article/pii/S0022311515301082
#    Description: … The degradation of thermal conductivity due to the non-… Degradation of thermal conductivity
# is predicted in (U x Th 1−… The reduction in thermal conductivity is most apparent at low …
#
# 102. Title: Thermal conductivity of (U, Pu) O2− x mixed oxide fuel
#    Link: https://www.sciencedirect.com/science/article/pii/0022311592904706
#    Description: … point of thermal diffusivity, we calculated thermal conductivity by … The conductivity values
# were then corrected to take into … state and to get an equivalent conductivity corresponding to the …
#
# 103. Title: Fabrication and Thermal Conductivity of (Th,U)O2 Pellets
#    Link: https://www.tandfonline.com/doi/abs/10.13182/NT04-A3518
#    Description: … O2 fuel were found to be lower than that of ThO2 or UO2 fuel. The degradation of the thermal
# conductivity by … Figures 8 and 9 show the thermal diffusivity and the thermal conductivity, …
#
# 104. Title: Thermal conductivity of hypostoichiometric low Pu content (U, Pu) O2− x mixed oxide
#    Link: https://www.sciencedirect.com/science/article/pii/S0022311599002056
#    Description: … The fuel thermal conductivity is derived using heat capacity … from stoichiometry on the
# conductivity smaller than what is … We propose a new thermal conductivity relation, which takes …
#
# 105. Title: Thermal conductivity of (U, Pu, Np) O2 solid solutions
#    Link: https://www.sciencedirect.com/science/article/pii/S0022311509000385
#    Description: … -MOX fuel, thermal physical properties such as melting point and thermal conductivity are
# important … When MAs are added to MOX fuel, these elements affect the thermal and mechanical …
#
# 106. Title: Method for measuring changes in the atmospheric O2/N2 ratio by a gas chromatograph equipped with a thermal conductivity detector
#    Link: https://agupubs.onlinelibrary.wiley.com/doi/abs/10.1029/2000JD900057
#    Description: … in their thermal conductivity from … thermal conductivity than most other gaseous compounds.
# We tested both H 2 and He for the o2/m 2 measurement and found the precision of the O2/N …
#
# 107. Title: The effect of plutonium content on the thermal conductivity of (U, Pu) O2 solid solutions
#    Link: https://www.sciencedirect.com/science/article/pii/0022311571900407
#    Description: … , to theoretical models dealing with thermal conductivity in dielectric solids. Thermal
# conductivity was determined in this study from measurements of thermal diffusivity using the laser …
#
# 108. Title: Thermal conductivity of near-stoichiometric (U, Nd) O2,(U, Sm) O2 and (U, Eu) O2 solid solutions
#    Link: https://www.sciencedirect.com/science/article/pii/0022311583902702
#    Description: … results, it is convenient to discuss the thermal resistivity, the reciprocal of the thermal
# conductivity. In the case of weak point-defect scattering of phonons, the thermal resistivity …
#
# 109. Title: Thermal conductivity of near-stoichiometric (U, Er) O2 solid solutions
#    Link: https://www.sciencedirect.com/science/article/pii/S0022311505001467
#    Description: … their thermal conductivities were calculated from the thermal … The temperature dependence
# of the thermal conductivity up to … The thermal conductivities of the UO 2 and (U, Er)O 2 solid …
#
# 110. Title: The Viscosity, Thermal Conductivity, and Prandtl Number for Air, O2, N2, NO, H2, CO, CO2, H2O, He, and A
#    Link: https://asmedigitalcollection.asme.org/fluidsengineering/article-abstract/76/6/967/1142301
#    Description: … experimental viscosity and thermal conductivity data for 12 … pilation and correlation of
# thermal data—thermodynamic as … are given for viscosity and thermal conductivity for most of the …
#
# 111. Title: The calculation of high-temperature equilibrium and nonequilibrium specific heat data for N2, O2 and NO
#    Link: https://arc.aiaa.org/doi/pdf/10.2514/6.1987-1633
#    Description: … for computing the partition functions and specific heats are not sufficiently accurate for the …
# partition functions, internal energies and internal specific heats for 0 2 , Nz and NO based on …
#
# 112. Title: Some Novel Energy‐Pooling Processes Involving O2 (1Δg)
#    Link: https://pubs.aip.org/aip/jcp/article-pdf/44/6/2529/11153377/2529_1_online.pdf
#    Description: … specific heat, with all but the lowest vibrational mode relaxed. The upper solid curve, (V",) 1-9,
# is that to be expected if the total vibrational specific heat … of the vibrational specific heat. At …
#
# 113. Title: Heat capacities of O2, N2, CO, and NO at low temperatures
#    Link: https://cdnsciencepub.com/doi/abs/10.1139/p69-004
#    Description: … In every case the specific heats showed an approximately T3 variation, and are displayed
# as … Our results show no evidence for a specific heat anomaly large enough to account for the …
#
# 114. Title: Real-gas properties of n-alkanes, O2, N2, H2O, CO, CO2, and H2 for diesel engine operation conditions
#    Link: https://link.springer.com/article/10.1134/S1990793109080090
#    Description: … heat at constant volume Cp, exc—excess specific heat at constant pressure … specific heat
# at constant volume Cp—real gas specific heat at constant pressure Cv —real gas specific heat …
#
# 115. Title: Specific heat and phase diagram of nonstoichiometric ceria (CeO2− x)
#    Link: https://www.sciencedirect.com/science/article/pii/002245968490135X
#    Description: … Changes in x are associated with a relatively large amount of O2 gas being absorbed or liber…
# of 5 cm3/sec the removal of O2 involves only approximately lo-i0 mole O2 per day. At lower …
#
# 116. Title: A Summary of Viscosity and Heat-Conduction Data for He, A, H2, O2, N2, CO, CO2, H2O, and Air
#    Link: https://asmedigitalcollection.asme.org/fluidsengineering/article-abstract/73/5/589/1144102
#    Description: … heat conductivities from the classical relationship X = C7)CV where X, rj, and Cv denote
# the heat conductivity, viscosity, and heat capacity, while e is a constant of proportionality. …
#
# 117. Title: Thermodynamic and transport properties of CO2, CO2–O2, and CO2–H2 mixtures at temperatures of 300 to 30,000 K and pressures of 0.1 to 10 MPa
#    Link: https://onlinelibrary.wiley.com/doi/abs/10.1002/eej.20467
#    Description: … The specific heat Cp of 50% mixtures of CO2 with H2 and O2 is shown in Fig. 9. When O2 is
# added… obtained in this study for the isobaric specific heats of H2 and O2 is shown in Table 3. …
#
# 118. Title: The Viscosity, Thermal Conductivity, and Prandtl Number for Air, O2, N2, NO, H2, CO, CO2, H2O, He, and A
#    Link: https://asmedigitalcollection.asme.org/fluidsengineering/article-abstract/76/6/967/1142301
#    Description: … Woolley concerned themselves with an improved method for correlating data of state for
# nonpolar molecules (4) and with a resonance method for measuring the ratio of specific heats, …
#
# 119. Title: Specific‐Heat Anomaly in Solidified Gases due to O2 Impurity
#    Link: https://pubs.aip.org/aip/jcp/article-abstract/49/2/763/211833
#    Description: … quite small dilutions of pure solid O2 with N2 are sufficient to depress … O2 concentrations,
# ~80%, in N2• Certainly our results show no trace of the anomaly in the specific heat of pure O2• …
#
# 120. Title: Adsorbed layers of O2 on graphite studied by heat capacity measurements
#    Link: https://www.sciencedirect.com/science/article/pii/0038109880903609
#    Description: … the temperature dependence of the heat capacity of different layers of 02 adsorbed on Grafoil
# between 23.5 and 26.5 K. The specific heat of layers below monolayer completion shows a …
#
# 121. Title: Band-gap tailoring of ZnO by means of heavy Al doping
#    Link: https://journals.aps.org/prb/abstract/10.1103/PhysRevB.37.10244
#    Description: … the conduction band in the form of an electron gas. In principle, the optical band gap can be
# … A widening occurs since thelowest states in the conduction band are blocked; this is the well…
#
# 122. Title: Carrier concentration dependence of band gap shift in n-type ZnO: Al films
#    Link: https://pubs.aip.org/aip/jap/article/101/8/083705/916155
#    Description: … BM band-filling and band gap renormalization effects, the former inducing a band gap …
# The band gap narrowing (Δ E BGN) derived from the band gap renormalization effect did …
#
# 123. Title: Band gap engineering of MnO 2 through in situ Al-doping for applicable pseudocapacitors
#    Link: https://pubs.rsc.org/en/content/articlehtml/2016/ra/c5ra26830c
#    Description: … electronegative Al source. The as-obtained Al-doped MnO 2 (ADM) shows narrower band gap
# and … The band gap of MnO 2 changes from 2.57 eV to 2.41 eV after Al-doping. The specific …
#
# 124. Title: Band Gap and Band Offset of  and  Alloys
#    Link: https://journals.aps.org/prapplied/abstract/10.1103/PhysRevApplied.10.011003
#    Description: … In the latter, the Al atoms occupy octahedral sites and Ga … We find that this choice of mixing
# parameter gives band gaps of … , formation enthalpies, and band gaps for Al2O3 and Ga2O3 …
#
# ...
#    Link: https://iopscience.iop.org/article/10.1088/1674-1056/acb48f/meta
#    Description: … The crystallization of amorphous TiCu is exhibited in amorphous parts of the Ti/TiCu DPNLs…
# of the amorphous TiCu is a process driven by stress and heat. Young's moduli for the Ti/TiCu …
#
# 381. Title: [HTML][HTML] Effects of density difference of constituent elements on glass formation in TiCu-based bulk metallic glasses
#    Link: https://www.sciencedirect.com/science/article/pii/S1002007113001305
#    Description: … which usually leads to large density differences among them as well… In this paper, such effects
# on glass-forming ability in a TiCu-… , the effects of density differences among the constituent …
#
# 382. Title: Electron momentum density distribution in TiCu
#    Link: https://www.sciencedirect.com/science/article/pii/S0966979511000227
#    Description: … TiCu alloy is reported. Using 59.54 keV gamma rays, the Compton profiles of TiCu alloy and
# … of the TiCu Compton line shape in terms of the Compton profiles of the constituent metals. …
#
# 383. Title: Densification and mechanical and antibacterial properties of low-cost powder metallurgy TiCu intermetallic alloy as a potential biomedical material
#    Link: https://link.springer.com/article/10.1007/s11837-020-04234-0
#    Description: … The relative densities of TiCu compacted specimens under 1 GPa pressure after … density
# of the sintered specimens was improved with the increase in temperature. The highest density …
#
# 384. Title: [HTML][HTML] Insights into alleviating high brittleness of TiCu compound by doping C and O as interstitials: First-principle calculations
#    Link: https://www.sciencedirect.com/science/article/pii/S2949822824001989
#    Description: … , the red charge regions denote increased charge density compared to undoped TiCu,
# pure … charge density. Essentially, the differential charge density distribution of doped TiCu …
#
# 385. Title: Electronic energy structure of TiCu and Ti2Cu
#    Link: https://link.springer.com/article/10.1023/A:1013185624613
#    Description: … 3d-density of state. The experimental fwhm of the fundamental maximum is 1.92 eV for
# TiCu and … , the spectrum is smoothed and its fine structure vanishes in the series Cu–TiCu–Ti2Cu. …
#
# 386. Title: First principles study on heterogeneous interfaces of TiCu alloys through aluminum addition
#    Link: https://www.sciencedirect.com/science/article/pii/S2352492824008559
#    Description: This paper investigates the heterogeneous nucleation interface resulting from the addition of
# Al element to TiCu alloy, focusing on the essential phases Ti 2 Cu and TiCu. Employing first …
#
# 387. Title: Rapid consolidation of nanostructured TiCu compound by high frequency induction heating and its mechanical properties
#    Link: https://www.jstage.jst.go.jp/article/matertrans/51/11/51_M2010251/_article/-char/ja/
#    Description: … toughness) of TiCu sintered from high energy ball milled TiCu is higher than those of … powder
# of TiCu and horizontally milled Ti+Cu powders. Near full density of TiCu could be obtained …
#
# 388. Title: Synthesis of TiC/Ti–Cu composites by pressureless reactive infiltration of TiCu alloy into carbon preforms fabricated by 3D-printing
#    Link: https://www.sciencedirect.com/science/article/pii/S0167577X0400936X
#    Description: … The skeleton density of the carbon preforms was measured by He-picnometry (AccuPyc … a
# TiCu alloy (50 wt.%Ti/50 wt.%Cu, Hauner Metallische Werkstoffe, Germany). The piece of TiCu …
#
# 389. Title: [PDF][PDF] Phase formation, thermal stability and mechanical behaviour of TiCu-based alloys
#    Link: https://core.ac.uk/download/pdf/236369967.pdf
#    Description: … The ∆h parameter describes the contribution of the work function difference (∆φ) and the
# electron density difference at the Wigner–Seitz cell boundary (∆nws) in a simplified Miedema’s …
#
# 390. Title: Dealloying behaviours of an equiatomic TiCu alloy
#    Link: https://www.jstage.jst.go.jp/article/matertrans/54/7/54_M2013033/_article/-char/ja/
#    Description: … the external cathodic current density of TiCu by the area ratio of the two phases, RA … TiCu
# phase is larger than that of the Ti2Cu phase (Fig. 3(a)). The dissolution rates of Ti2Cu and TiCu …
#
# 391. Title: Tailoring martensitic transformation behavior in TiCu-based super-elastic alloys and their composites
#    Link: https://s-space.snu.ac.kr/handle/10371/140646
#    Description: … behavior in a wider range of strain and higher absorbed energy. Fig. 4.2(a) shows the DSC
# … phase(σy,M), energy absorbed by compressive deformation until fracture occurred(Eab) and …
#
# 392. Title: [PDF][PDF] Phase formation, thermal stability and mechanical behaviour of TiCu-based alloys
#    Link: https://core.ac.uk/download/pdf/236369967.pdf
#    Description: PhD Dissertation_Piter Gargarella_final Page 1 Phase formation, thermal stability and
# mechanical behaviour of TiCu-based alloys Thesis for the partial fulfillment of the requirements for …
#
# 393. Title: Comparison of hydrogen absorption in glassy and crystalline structures
#    Link: https://www.sciencedirect.com/science/article/pii/B9780080227153500400
#    Description: … TiCu and Ti 2 Cu which normally, of course, are crystalline. Absorption of hydrogen by crystalline
# TiCu … Crystalline Ti 2 Cu and TiCu formed intermetallic compound hydrides, Ti 2 CUH <…
#
# 394. Title: Biocompatibility, osseointegration, antibacterial and mechanical properties of nanocrystalline Ti-Cu alloy as a new orthopedic material
#    Link: https://www.sciencedirect.com/science/article/pii/S0927776520301193
#    Description: … TiCu alloy prepared by vacuum sintering in this work is about 50 % higher than the value
# reported by Shon et al. [22] for TiCu prepared by high energy … lead to increased absorption of …
#
# 395. Title: Dual optimization of energy-absorbing intermediate layer for diversified enhancement of heterogeneous brazed joints
#    Link: https://link.springer.com/article/10.1007/s40194-024-01705-9
#    Description: … The reaction layer of TB10 had a thickness of about 14 μm and was composed of TiCu (Fig.
# 5b). Region III was the brazing seam, which was mainly composed of white Ag(s,s) and gray …
#
# 396. Title: Study of TiCuN/ZrN multilayer coatings with adjustable combination properties deposited on TiCu alloy
#    Link: https://www.sciencedirect.com/science/article/pii/S0042207X22003281
#    Description: … In recent years, Ti-5wt %Cu (TiCu) alloy has been reported … The results confirmed that TiCu
# alloy could also significantly … implant devices, this study took TiCu as the substrate material to …
#
# 397. Title: Characterization and hardness of TiCu–Ti2Cu3 intermetallic material fabricated by mechanical alloying and subsequent annealing
#    Link: https://iopscience.iop.org/article/10.1088/2053-1591/3/4/045004/meta
#    Description: … properties; eg, they have good sound absorption capacity and high electric conduction [1].
# Cu… this system at room temperature include: TiCu 4 , Ti 2 Cu 3 , Ti 3 Cu 4 , TiCu, Ti 2 Cu and Ti …
#
# 398. Title: Layer thickness dependent plastic deformation mechanism in Ti/TiCu dual-phase nano-laminates
#    Link: https://iopscience.iop.org/article/10.1088/1674-1056/acb48f/meta
#    Description: … dislocations emitted from the crystalline phase will be absorbed by the ACI infinitely. On the
# other … , good sound absorption, and electric conductivity. [28] B2 phase is often observed in …
#
# 399. Title: [HTML][HTML] Dealloyed nano-porous TiCu coatings with controlled copper release for cardiovascular devices
#    Link: https://www.sciencedirect.com/science/article/pii/S277295082300451X
#    Description: … Among the various materials used as coatings in this domain, TiCu coatings have gained
# particular attention as they exhibit favorable biocompatibility under the controlled release of …
#
# 400. Title: Dealloying of an amorphous TiCuRu alloy results in a nanostructured electrocatalyst for hydrogen evolution reaction
#    Link: https://onlinelibrary.wiley.com/doi/abs/10.1002/cey2.322
#    Description: … their low Gibbs free energy of Hydrogen absorption and high … the Gibbs free energy of
# hydrogen absorption of Cu and thus … In this study, amorphous TiCu and TiCuRu alloy ribbons with …
#
# 401. Title: Effect of Ti contents on interfacial bonding, mechanical and thermal properties of Mo-Cu composites
#    Link: https://link.springer.com/article/10.1007/s42864-023-00258-6
#    Description: … (TiCu + Ti 2 Cu + Ti). This step structure not only has a smaller thermal conductivity cross-…
# the unit area, but also provides more thermal conductivity channels to promote rapid heat …
#
# 402. Title: Explorations of stability, mechanical and thermal properties of cubic TiM2Al (M= Fe, Co, Ni, and Cu) compounds
#    Link: https://www.sciencedirect.com/science/article/pii/S0038109821003215
#    Description: … Moreover, we believe that TiCu 2 Al has a good match between strength and toughness. …
# the thermal conductivity is, thereby the TiFe 2 Al has the largest thermal conductivity compared …
#
# 403. Title: Effect of Ti and Zr on high temperature mechanical and thermal properties of MoCu composites
#    Link: https://www.sciencedirect.com/science/article/pii/S1044580324000159
#    Description: … reference to the phase diagram of the TiCu binary alloy, it can be seen … thermal conductivity
# of 60Mo40Cu composites in this study reached 220.81 W/(m·k), so the thermal conductivity …
#
# 404. Title: Thermal conductivity of Cu-Ti/diamond composites via spark plasma sintering
#    Link: https://www.sciencedirect.com/science/article/pii/S0925963518308665
#    Description: … + 2.278TJ/moland 1 5 Ti + 4 5 Cu → 1 5 TiCu 4 , ΔG = − 6011 + 2.339TJ/mol. ΔG in the
# formation of TiC, Ti 2 Cu, TiCu, Ti 3 Cu 4 and TiCu 4 was calculated to be −84,882J/mol, −6414.7J…
#
# 405. Title: [HTML][HTML] Fabrication, characterization and implementation of thermo resistive ticu (N, O) thin films in a polymer injection mold
#    Link: https://www.mdpi.com/1996-1944/13/6/1423
#    Description: … of steel inserts with metallic thermoresistive TiCu(O,N) thin films … TiCu(O,N) systems can
# be optimized depending on the flux of N 2 + O 2 , the morphological, structural and low thermal …
#
# 406. Title: Assessment of melting behavior of Cu-coated Ti powders using thermal analysis
#    Link: https://www.sciencedirect.com/science/article/pii/S0921509303013066
#    Description: … then a significant thermal event at 870 C, corresponding to Ti 2 Cu 3 transforming to TiCu 2
# , … a microstructure close to that of the TiCu 2 –TiCu 4 eutectic. With continued heating above …
#
# 407. Title: Effects of titanium addition on the microstructure of carbon/copper composite materials
#    Link: https://www.sciencedirect.com/science/article/pii/S0038109806009288
#    Description: … comparatively high thermal conductivity, the thermal conductivity is … produced because of the
# high thermal conductivity of Cu. … TiCu 2 compounds, which results in the increase of thermal …
#
# 408. Title: Conductive TiC/Ti–Cu/C composites fabricated by Ti–Cu alloy reactive infiltration into 3D-printed carbon performs
#    Link: https://journals.sagepub.com/doi/abs/10.1177/0021998314541307
#    Description: … Copper-based matrix composites are commonly employed in applications where a good
# electrical and/or thermal conductivity is required. Because of the high electrical conductivity of …
#
# 409. Title: Synthesis of TiC/Ti–Cu composites by pressureless reactive infiltration of TiCu alloy into carbon preforms fabricated by 3D-printing
#    Link: https://www.sciencedirect.com/science/article/pii/S0167577X0400936X
#    Description: … Copper based matrix composites are extensively employed in applications where a good
# electrical and/or thermal conductivity is required. Among the numerous applications of Cu and …
#
# 410. Title: Vacuum diffusion bonding of TC4 titanium alloy and T2 copper by a slow cooling heat treatment
#    Link: https://www.sciencedirect.com/science/article/pii/S0924013622001078
#    Description: … Fracture occurred mainly in the interface of TiCu and TiCu 2 phases, with many dimples, …
# engineering fields with superior electrical and thermal conductivity, superior cold and hot …
#
# 411. Title: [PDF][PDF] Phase formation, thermal stability and mechanical behaviour of TiCu-based alloys
#    Link: https://core.ac.uk/download/pdf/236369967.pdf
#    Description: … A candidate to form new shape memory BMG composites is the pseudo-binary TiCuTiNi
# system because bulk glassy samples with a critical casting thickness of around 1 mm have been …
#
# 412. Title: Tailoring martensitic transformation behavior in TiCu-based super-elastic alloys and their composites
#    Link: https://s-space.snu.ac.kr/handle/10371/140646
#    Description: … temperature (Af)) of reversible martensitic transformation with heating/cooling rates of 10
# K min-1. nd specific heat. Specific heat was determined by DSC in the temperature range of …
#
# 413. Title: Specifics of crystallization of amorphous TiNiCu alloys with high concentrations of copper
#    Link: https://link.springer.com/article/10.1134/S1063783420060281
#    Description: … Thin ribbons of alloys of the quasi-binary TiNi–TiCu system fabricated by rapid quenching
# from melt are promising materials for microactuators [2] due to their narrow temperature …
#
# 414. Title: Effect of Ti contents on interfacial bonding, mechanical and thermal properties of Mo-Cu composites
#    Link: https://link.springer.com/article/10.1007/s42864-023-00258-6
#    Description: … of interface region in the 40Mo30Cu30Ti composite: a–c interface morphology of Mo and Ti
# 2 Cu; d–f interface morphology of TiCu and Ti 2 Cu; g–i interface morphology of Mo and TiCu …
#
# 415. Title: Thermal stability of amorphous Ti-Cu alloys
#    Link: https://www.sciencedirect.com/science/article/pii/0001616083900755
#    Description: … y-TiCu phase was observed in the diagram of a Ti,,Cu~, sample that had been heated to …
# composition a mixture of the phases Ti&u and TiCu is expected to be in thermal equilibrium …
#
# 416. Title: Phase diagram of the system titanium-copper
#    Link: https://link.springer.com/article/10.1007/bf00775543
#    Description: … The compound TiCu 4 may be expected to have an elementary cell with 20 atoms and a …
# the TiCu a ceil The density values obtained by caIculation from x-ray diffraction data for TiCu 4 …
#
# 417. Title: First principles study on heterogeneous interfaces of TiCu alloys through aluminum addition
#    Link: https://www.sciencedirect.com/science/article/pii/S2352492824008559
#    Description: … of Al element to TiCu alloy, focusing on the essential phases Ti 2 Cu and TiCu. Employing
# first … Initially, the lattice mismatch between Al/Ti 2 Cu and Al/TiCu interfaces is calculated to …
#
# 418. Title: Plasticity of a TiCu-based bulk metallic glass: Effect of cooling rate
#    Link: https://www.cambridge.org/core/journals/journal-of-materials-research/article/plasticity-of-a-ticubased-bulk-metallic-glass-effect-of-cooling-rate/45FABB631F7654FBD84C501797284106
#    Description: … In this paper, we have demonstrated that the ductility of the TiCu-based metallic glass …
# bands can also be applied to the present ductile TiCu-base alloy. Based on that the volume …
#
# 419. Title: Vacuum diffusion bonding of TC4 titanium alloy and T2 copper by a slow cooling heat treatment
#    Link: https://www.sciencedirect.com/science/article/pii/S0924013622001078
#    Description: … Fracture occurred mainly in the interface of TiCu and TiCu 2 phases, with many dimples,
# revealing clearly ductile mode. Cu element near the interface had a larger diffusion capacity …
#
# 420. Title: On the selection of Ti–Cu alloys for thixoforming processes: phase diagram and microstructural evaluation
#    Link: https://link.springer.com/article/10.1007/s10853-015-9367-4
#    Description: … to the TiCu phase… TiCu from the Ti 2 Cu particles using metallographic observation, as a
# result of the minimal difference in contrast between the two phases and the small content of TiCu…
